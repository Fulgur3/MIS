# %% [markdown]
# # <span style="color: blue; border:2px solid #555555; padding: 5px">Буркіна-Фасо</span>
#
#
# ## **Огляд**
#
# Буркіна-Фасо - країна в Західній Африці. Вона має спільний кордон із шістьма країнами: на півночі з Малі, на сході з Нігером, на південному сході з Беніном, на півдні з Того і Ганою, а на південному заході з Кот-д'Івуаром.
#
# ## **Основна Інформація**
#
# - **Площа**: *274 200 квадратних кілометрів*
# - **Населення**: *Приблизно 21 мільйон осіб*
#
# ## **Уряд**
#
# - **Тип Уряду**: *Унітарна напівпрезидентська республіка*
# - **Президент**: *Рош Марк Кріштіан Каборе*
#
# ## **Відомі Особистості**
#
# - **Томас Санкара**: *Попередній Президент і революційний лідер, відомий своєю прогресивною політикою.*
# - **Блез Компаоре**: *Попередній Президент, який правив 27 років до свого свергнення у 2014 році.*
#
# ## **Пам'ятки та Природні Об'єкти**
#
# - **Насціональний Парк В**: *Об'єкт Світової Спадщини ЮНЕСКО, відомий своєю різноманітною фауною.*
# - **Руїни Лоропені**: *Давні кам'яні руїни, які, ймовірно, належать 11-15 століттям.*
# - **Піки Сіндоу**: *Унікальні гірські формації в регіоні Банфора.*
#
#
# ## **Флаг Буркіна-Фасо**
#
#
#
# ![Вайб буркіна фасо1](Flag_of_Burkina_Faso.svg.png)
#
#
# ## **Таблиця: Населення за Регіонами**
#
# | Регіон       | Населення (мільйони) |
# |--------------|-----------------------|
# | Сахель       | 2.5                   |
# | Центральний  | 5.6                   |
# | Південний    | 7.8                   |

# %%
def task_2():
    try:
        num1 = int(input("Введіть перше ціле число: "))
        num2 = int(input("Введіть друге ціле число: "))
    except ValueError:
        print("Помилка: введені дані повинні бути цілими числами!")

    while num2:
        num1, num2 = num2, num1 % num2
    
    return num1

def test2():
    result = task_2()
    print("Найбільший спільний дільник:", result)

# %%
test2()
# Out:
# Найбільший спільний дільник: 13
